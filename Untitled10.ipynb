# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

# Load data from Excel file
file_path = 'C:\\Users\\kathu\\Downloads\\Discs Dataset.xlsx'
sheet_name_thickness = 'Thickness 1'  
sheet_name_gap = 'Gap 2'
sheet_name_height = 'Height'
sheet_name_thickness_2 = 'Thickness 2'
sheet_name_gap_1 = 'Gap 1'

sheet_name_dia_3 = 'Diameter 3'  
sheet_name_dia_2 = 'Diameter 2' 


data_thickness = pd.read_excel(file_path, sheet_name=sheet_name_thickness)
data_thickness_2 = pd.read_excel(file_path, sheet_name=sheet_name_thickness_2)

data_gap_1 = pd.read_excel(file_path, sheet_name=sheet_name_gap_1)
data_gap = pd.read_excel(file_path, sheet_name=sheet_name_gap)

data_height = pd.read_excel(file_path, sheet_name=sheet_name_height)

data_dia_3 = pd.read_excel(file_path, sheet_name=sheet_name_dia_3)
data_dia_2 = pd.read_excel(file_path, sheet_name=sheet_name_dia_2)


all_x_m = []
all_y_m = []

all_x_s = []
all_y_s = []

data=2000

# %%
def extract_diameters(diameter_str, max_length=6):
    diameters = []
    for x in diameter_str.split('nm'):
        if x:
            diameters.append(int(x))
    padded_diameters = diameters + [np.nan] * (max_length - len(diameters))
    mask = [1] * len(diameters) + [0] * (max_length - len(diameters))
    return padded_diameters, mask

# %%
wavelength = data_thickness['Wavelength (nm)'].values

# Define thickness values to interpolate
thickness_values = [5, 10, 15, 20, 30, 50, 80, 100]

constant_non_uniform_diameter = "60nm80nm100nm120nm"

# Function to extract individual diameters and pad with NaN

# Process each thickness value
for thickness in thickness_values:
    extension_ratio = data_thickness[f'{thickness} nm'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for thickness in thickness_values:
    extension_ratio = data_thickness[f'{thickness} nm.1'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
wavelength = data_thickness_2['Wavelength (nm)'].values

# Define thickness values to interpolate
thickness_values = [2,4,6,8,10,15,20,25,30,40,50,70,80,100]

# Constant non-uniform diameter string
constant_non_uniform_diameter = "40nm60nm80nm100nm120nm"

# Function to extract individual diameters and pad with NaN

# Process each thickness value
for thickness in thickness_values:
    extension_ratio = data_thickness_2[f'{thickness}nm'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for thickness in thickness_values:
    extension_ratio = data_thickness_2[f'{thickness}nm.1'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
wavelength = data_gap_1['Wavelength (nm)'].values

gap_values = [4,5,6,8,10,15]

constant_non_uniform_diameter = "40nm60nm80nm100nm120nm"

# Process each gap value
for gap in gap_values:
    extension_ratio = data_gap_1[f'{gap} nm'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input array with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for gap in gap_values:
    extension_ratio = data_gap_1[f'{gap} nm.1'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input array with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
wavelength = data_gap['Wavelength (nm)'].values

gap_values = [5, 10, 15, 20]

constant_non_uniform_diameter = "60nm80nm100nm120nm"

# Process each gap value
for gap in gap_values:
    extension_ratio = data_gap[f'{gap} nm'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input array with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for gap in gap_values:
    extension_ratio = data_gap[f'{gap} nm.1'].values  # Assuming the column name follows this pattern

    # Interpolation
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    # Generate interpolated values for a range of wavelengths
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input array with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)

    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
wavelength = data_gap['Wavelength (nm)'].values

height_values = [30, 50, 80, 100, 120, 150]

constant_non_uniform_diameter = "40nm60nm80nm100nm120nm"

for height in height_values:

    extension_ratio = data_height[f'{height} nm'].values

    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)
    
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), height)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

        # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

        # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

        # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for height in height_values:

    extension_ratio = data_height[f'{height} nm.1'].values

    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)
    
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), height)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), 5)  # Assume a constant gap for thickness data
    wavelength_array = wavelength_range.reshape(batch_size, 1)

        # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(constant_non_uniform_diameter)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

        # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

        # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Combine all data
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
non_uniform_diameter_values = [
    "80nm100nm",
    "60nm80nm100nm",
    "60nm80nm100nm120nm",
    "40nm60nm80nm100nm120nm",
    "40nm60nm80nm100nm120nm140nm"
]


# Process each non-uniform diameter value
for non_uniform_diameter in non_uniform_diameter_values:
    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(non_uniform_diameter)

    # Interpolation for height data
    extension_ratio = data_dia_3[f'{non_uniform_diameter}'].values
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), 5)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Convert lists to numpy arrays
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for non_uniform_diameter in non_uniform_diameter_values:
    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(non_uniform_diameter)

    # Interpolation for height data
    extension_ratio = data_dia_3[f'{non_uniform_diameter}.1'].values
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 50)
    gap_array = np.full((batch_size, 1), 5)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Convert lists to numpy arrays
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
non_uniform_diameter_values = [
    "60nm80nm",
    "80nm100nm",
    "60nm80nm100nm",
    "60nm80nm100nm120nm",
    "40nm60nm80nm100nm120nm",
    "40nm60nm80nm100nm120nm140nm"
]


# Process each non-uniform diameter value
for non_uniform_diameter in non_uniform_diameter_values:
    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(non_uniform_diameter)

    # Interpolation for height data
    extension_ratio = data_dia_2[f'{non_uniform_diameter}'].values
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 10)
    gap_array = np.full((batch_size, 1), 5)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    x = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_m.append(x)
    all_y_m.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Convert lists to numpy arrays
x = np.vstack(all_x_m)
y = np.vstack(all_y_m)

for non_uniform_diameter in non_uniform_diameter_values:
    # Extract individual diameters and mask
    diameter_array, mask_array = extract_diameters(non_uniform_diameter)

    # Interpolation for height data
    extension_ratio = data_dia_2[f'{non_uniform_diameter}'].values
    interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')
    wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
    interpolated_extension_ratios = interpolation_function(wavelength_range)

    # Create input arrays with constants and varying inputs
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), 50)
    thickness_array = np.full((batch_size, 1), 10)
    gap_array = np.full((batch_size, 1), 5)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.tile(np.array(diameter_array), (batch_size, 1))
    mask_array = np.tile(np.array(mask_array), (batch_size, 1))

    # Create the input array
    s_feat = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)

    # Append to storage
    all_x_s.append(s_feat)
    all_y_s.append(interpolated_extension_ratios.reshape(batch_size, 1))

# Convert lists to numpy arrays
s_feat = np.vstack(all_x_s)
s_y = np.vstack(all_y_s)

# %%
# all_x_s = np.vstack(all_x_s)

# # Convert to DataFrame

# columns=['height','thickness','gap','wavelength','dia1','dia2','dia3','dia4','dia5','dia6']

# df = pd.DataFrame(all_x_s,columns=columns)
# # Save to CSV
# csv_path = 'C:\\Users\\kathu\\OneDrive\\Desktop\\train_data.csv'
# df.to_csv(csv_path, index=False,columns=columns)
# print(f"Data saved to {csv_path}")

# %%
x[np.isnan(x)] = -1
y[np.isnan(y)] = -1

s_feat[np.isnan(s_feat)] = -1
s_y[np.isnan(s_y)] = -1

# Generate shuffled indices
shuffled_indices = np.random.permutation(len(x))
x_shuffled = x[shuffled_indices]
y_shuffled = y[shuffled_indices]

shuffled_indices = np.random.permutation(len(s_feat))
s_feat_shuffled = s_feat[shuffled_indices]
s_y_shuffled = s_y[shuffled_indices]

x_train, x_test, y_train, y_test = train_test_split(x_shuffled, y_shuffled, test_size=0.1, random_state=42)
x_train_s, x_test_s, y_train_s, y_test_s = train_test_split(s_feat_shuffled, s_y_shuffled, test_size=0.1, random_state=42)



# df_x_train = pd.DataFrame(x_train, columns=[f'feature_{i+1}' for i in range(x_train.shape[1])])
# df_y_train = pd.DataFrame(y_train, columns=['target'])

# df_train = pd.concat([df_x_train, df_y_train], axis=1)


# df_train.to_csv('C:\\Users\\kathu\\OneDrive\\Desktop\\train_data.csv', index=False)

# %%
# df_x_train = pd.DataFrame(x_train, columns=[f'feature_{i+1}' for i in range(x_train.shape[1])])
# df_y_train = pd.DataFrame(y_train, columns=['target'])

# df_train = pd.concat([df_x_train, df_y_train], axis=1)


# df_train.to_csv('C:\\Users\\kathu\\OneDrive\\Desktop\\train_data.csv', index=False)

# %%
# For the first dataset
scaler_x = StandardScaler()
scaler_y = StandardScaler()
x_train_scaled = scaler_x.fit_transform(x_train)
x_test_scaled = scaler_x.transform(x_test)
y_train_scaled = scaler_y.fit_transform(y_train)  # No need to reshape, already (88200, 1)
y_test_scaled = scaler_y.transform(y_test)  # Assuming y_test has shape (n_samples, 1)

# For the second dataset
scaler_x_s = StandardScaler()
scaler_y_s = StandardScaler()
x_train_scaled_s = scaler_x_s.fit_transform(x_train_s)
x_test_scaled_s = scaler_x_s.transform(x_test_s)
y_train_scaled_s = scaler_y_s.fit_transform(y_train_s)  # Assuming y_train_s has shape (n_samples, 1)
y_test_scaled_s = scaler_y_s.transform(y_test_s)  # Assuming y_test_s has shape (n_samples, 1)

# %%
model = Sequential([
    Dense(32, input_dim=x.shape[1], activation='relu'),  # First hidden layer with 32 neurons
    Dense(64, activation='relu'),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),  
    Dense(1, activation='linear')  
])

# Compile the model
model.compile(optimizer='adam', loss='mse',metrics=['mae'])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(x_train_scaled, y_train_scaled, epochs=500, batch_size=32, validation_data=(x_test_scaled, y_test_scaled), verbose=1, callbacks=[early_stopping])

# Evaluate the model using Mean Absolute Error (MAE)
predictions_scaled = model.predict(x_test_scaled)
predictions = scaler_y.inverse_transform(predictions_scaled)
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# C:\Users\kathu\anaconda3\envs\py310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 13s 3ms/step - loss: 0.0949 - mae: 0.1773 - val_loss: 0.0133 - val_mae: 0.0647
# Epoch 2/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0093 - mae: 0.0601 - val_loss: 0.0044 - val_mae: 0.0438
# Epoch 3/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0064 - mae: 0.0514 - val_loss: 0.0033 - val_mae: 0.0346
# Epoch 4/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0048 - mae: 0.0435 - val_loss: 0.0119 - val_mae: 0.0727
# Epoch 5/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0037 - mae: 0.0382 - val_loss: 0.0026 - val_mae: 0.0287
# Epoch 6/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0021 - mae: 0.0287 - val_loss: 0.0017 - val_mae: 0.0290
# Epoch 7/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0021 - mae: 0.0284 - val_loss: 0.0014 - val_mae: 0.0207
# Epoch 8/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0019 - mae: 0.0259 - val_loss: 0.0010 - val_mae: 0.0234
# Epoch 9/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0022 - mae: 0.0284 - val_loss: 0.0016 - val_mae: 0.0289
# Epoch 10/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0016 - mae: 0.0230 - val_loss: 0.0011 - val_mae: 0.0201
# Epoch 11/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0012 - mae: 0.0205 - val_loss: 0.0044 - val_mae: 0.0373
# Epoch 12/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.0015 - mae: 0.0222 - val_loss: 6.3062e-04 - val_mae: 0.0178
# Epoch 13/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0017 - mae: 0.0242 - val_loss: 0.0019 - val_mae: 0.0227
# Epoch 14/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - loss: 0.0010 - mae: 0.0187 - val_loss: 5.7840e-04 - val_mae: 0.0159
# Epoch 15/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0014 - mae: 0.0221 - val_loss: 0.0014 - val_mae: 0.0215
# Epoch 16/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0015 - mae: 0.0215 - val_loss: 0.0016 - val_mae: 0.0243
# Epoch 17/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0014 - mae: 0.0210 - val_loss: 0.0011 - val_mae: 0.0207
# Epoch 18/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.0014 - mae: 0.0210 - val_loss: 4.0793e-04 - val_mae: 0.0105
# Epoch 19/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 7.6903e-04 - mae: 0.0161 - val_loss: 0.0013 - val_mae: 0.0187
# Epoch 20/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 9.3301e-04 - mae: 0.0164 - val_loss: 3.2086e-04 - val_mae: 0.0129
# Epoch 21/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 0.0013 - mae: 0.0211 - val_loss: 3.6608e-04 - val_mae: 0.0121
# Epoch 22/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.0011 - mae: 0.0181 - val_loss: 4.2744e-04 - val_mae: 0.0147
# Epoch 23/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 561s 204ms/step - loss: 0.0010 - mae: 0.0185 - val_loss: 4.4618e-04 - val_mae: 0.0116
# Epoch 24/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - loss: 7.0565e-04 - mae: 0.0161 - val_loss: 9.9238e-04 - val_mae: 0.0199
# Epoch 25/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 12s 4ms/step - loss: 9.8450e-04 - mae: 0.0181 - val_loss: 1.9247e-04 - val_mae: 0.0089
# Epoch 26/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - loss:
compile(optimizer='adam', loss='mse', metrics=['mae'])

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model with early stopping
history_s = model_s.fit(x_train_scaled_s, y_train_scaled_s, 
                        epochs=500, batch_size=32, 
                        validation_data=(x_test_scaled_s, y_test_scaled_s),  # Correct validation data
                        verbose=1, callbacks=[early_stopping])
 
# Evaluate the model using Mean Absolute Error (MAE)
predictions_scaled_s = model_s.predict(x_test_scaled_s)
predictions_s = scaler_y_s.inverse_transform(predictions_scaled_s)  # Use the correct scaler for the second dataset
mae_s = mean_absolute_error(y_test_s, predictions_s)
print(f'Mean Absolute Error (MAE): {mae_s}')
# Out:
# C:\Users\kathu\anaconda3\envs\py310\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 60s 18ms/step - loss: 0.2232 - mae: 0.3270 - val_loss: 0.0735 - val_mae: 0.1938
# Epoch 2/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 47s 17ms/step - loss: 0.0727 - mae: 0.1765 - val_loss: 0.0441 - val_mae: 0.1324
# Epoch 3/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 53s 19ms/step - loss: 0.0438 - mae: 0.1249 - val_loss: 0.0395 - val_mae: 0.1030
# Epoch 4/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 0.0389 - mae: 0.1133 - val_loss: 0.0383 - val_mae: 0.1054
# Epoch 5/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - loss: 0.0366 - mae: 0.1077 - val_loss: 0.0286 - val_mae: 0.0876
# Epoch 6/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 43s 16ms/step - loss: 0.0334 - mae: 0.0963 - val_loss: 0.0408 - val_mae: 0.1072
# Epoch 7/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 44s 16ms/step - loss: 0.0356 - mae: 0.1002 - val_loss: 0.0509 - val_mae: 0.1416
# Epoch 8/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 0.0354 - mae: 0.0991 - val_loss: 0.0328 - val_mae: 0.0883
# Epoch 9/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - loss: 0.0323 - mae: 0.0922 - val_loss: 0.0332 - val_mae: 0.0960
# Epoch 10/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 0.0312 - mae: 0.0903 - val_loss: 0.0274 - val_mae: 0.0750
# Epoch 11/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 44s 16ms/step - loss: 0.0289 - mae: 0.0806 - val_loss: 0.0263 - val_mae: 0.0717
# Epoch 12/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 44s 16ms/step - loss: 0.0283 - mae: 0.0794 - val_loss: 0.0238 - val_mae: 0.0591
# Epoch 13/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - loss: 0.0292 - mae: 0.0809 - val_loss: 0.0280 - val_mae: 0.0818
# Epoch 14/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - loss: 0.0273 - mae: 0.0763 - val_loss: 0.0320 - val_mae: 0.0873
# Epoch 15/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 38s 14ms/step - loss: 0.0286 - mae: 0.0760 - val_loss: 0.0266 - val_mae: 0.0769
# Epoch 16/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 0.0276 - mae: 0.0749 - val_loss: 0.0262 - val_mae: 0.0722
# Epoch 17/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 41s 13ms/step - loss: 0.0285 - mae: 0.0760 - val_loss: 0.0268 - val_mae: 0.0751
# Epoch 18/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 0.0270 - mae: 0.0744 - val_loss: 0.0305 - val_mae: 0.0899
# Epoch 19/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 36s 13ms/step - loss: 0.0272 - mae: 0.0739 - val_loss: 0.0248 - val_mae: 0.0672
# Epoch 20/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step - loss: 0.0266 - mae: 0.0705 - val_loss: 0.0256 - val_mae: 0.0669
# Epoch 21/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 35s 13ms/step - loss: 0.0268 - mae: 0.0719 - val_loss: 0.0282 - val_mae: 0.0811
# Epoch 22/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 0.0261 - mae: 0.0711 - val_loss: 0.0245 - val_mae: 0.0605
# Epoch 23/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 37s 13ms/step - loss: 0.0261 - mae: 0.0687 - val_loss: 0.0248 - val_mae: 0.0667
# Epoch 24/500
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 37s 14ms/step
# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_predictions(thickness, height, gap, dia1, dia2, dia3, dia4, dia5, dia6):
    # Generate a range of wavelengths
    wavelength_range = np.linspace(400, 2500, data)
    
    # Create input array with constants and varying wavelength
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), height)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.array([[dia1, dia2, dia3, dia4, dia5, dia6]] * batch_size)  # Replicate for each wavelength
    
    # Concatenate all inputs to form the final input batch
    x_input = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)
    
    # Scale the inputs
    x_input_scaled = scaler_x.transform(x_input)
    
    # Predict using the trained model
    predictions_scaled = model.predict(x_input_scaled)
    predictions = scaler_y.inverse_transform(predictions_scaled)
    
    return wavelength_range, predictions

# Example usage:
thickness_example = 10
height_example = 50
gap_example = 10
dia1_example = 60
dia2_example = 80
dia3_example = 100
dia4_example = 120
dia5_example = -1
dia6_example = -1

wavelength_range_example, predictions_example = plot_predictions(thickness_example, height_example, gap_example,
                                                                 dia1_example, dia2_example, dia3_example,
                                                                 dia4_example, dia5_example, dia6_example)

# Plotting the graph
plt.figure(figsize=(15, 5))
plt.plot(wavelength_range_example, predictions_example, label='Predictions')
plt.xlabel('Wavelength')
plt.ylabel('Predicted Value')
plt.title('Predictions vs Wavelength')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_predictions_s(thickness, height, gap, dia1, dia2, dia3, dia4, dia5, dia6):
    # Generate a range of wavelengths
    wavelength_range = np.linspace(400, 2500, data)  # Assuming 'data' is defined elsewhere
    
    # Create input array with constants and varying wavelength
    batch_size = len(wavelength_range)
    length_array = np.full((batch_size, 1), height)
    thickness_array = np.full((batch_size, 1), thickness)
    gap_array = np.full((batch_size, 1), gap)
    wavelength_array = wavelength_range.reshape(batch_size, 1)
    diameter_array = np.array([[dia1, dia2, dia3, dia4, dia5, dia6]] * batch_size)  # Replicate for each wavelength
    
    # Concatenate all inputs to form the final input batch
    x_input = np.concatenate([length_array, thickness_array, gap_array, wavelength_array, diameter_array], axis=1)
    
    # Scale the inputs using the scaler for model_s
    x_input_scaled = scaler_x_s.transform(x_input)
    
    # Predict using the trained model_s
    predictions_scaled = model_s.predict(x_input_scaled)
    predictions = scaler_y_s.inverse_transform(predictions_scaled)
    
    return wavelength_range, predictions

# Example usage for model_s:
thickness_example = 10
height_example = 50
gap_example = 10
dia1_example = 60
dia2_example = 80
dia3_example = 100
dia4_example = 120
dia5_example = -1
dia6_example = -1

wavelength_range_example_s, predictions_example_s = plot_predictions_s(thickness_example, height_example, gap_example,
                                                                       dia1_example, dia2_example, dia3_example,
                                                                       dia4_example, dia5_example, dia6_example)

# Plotting the graph for model_s
plt.figure(figsize=(15, 5))
plt.plot(wavelength_range_example_s, predictions_example_s, label='Predictions (model_s)')
plt.xlabel('Wavelength')
plt.ylabel('Predicted Value')
plt.title('Predictions vs Wavelength (model_s)')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
df1 = pd.read_excel("C:\\Users\\kathu\\Downloads\\Discs Check 1.xlsx")

wavelength = df1['Wavelength (nm)'].values
extension_ratio = df1['M State'].values

interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
interpolated_extension_ratio_m = interpolation_function(wavelength_range)


plt.plot(wavelength_range, interpolated_extension_ratio_m, label='actual')
plt.grid(True)

# %%
df1 = pd.read_excel("C:\\Users\\kathu\\Downloads\\Discs Check 1.xlsx")

wavelength = df1['Wavelength (nm)'].values
extension_ratio = df1['S State'].values

interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
interpolated_extension_ratio_s = interpolation_function(wavelength_range)


plt.plot(wavelength_range, interpolated_extension_ratio_s, label='actual')
plt.grid(True)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
from sklearn.metrics import r2_score

# Calculate the R^2 score


# Calculate error metrics
mae = mean_absolute_error(interpolated_extension_ratios, predictions_example)
mse = mean_squared_error(interpolated_extension_ratios, predictions_example)
r2 = r2_score(interpolated_extension_ratios, predictions_example)
rmse = np.sqrt(mse)

# Print the error metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R^2 Score: {r2:.2f}")

# Optionally, plot the difference between the actual and predicted values
plt.plot(wavelength_range_example, predictions_example, label='Predictions')
plt.plot(wavelength_range, interpolated_extension_ratios, label='Actual')
plt.grid(True)
plt.legend()
# Out:
# Mean Absolute Error (MAE): 0.059765803389647175
# Mean Squared Error (MSE): 0.00790277850689144
# Root Mean Squared Error (RMSE): 0.08889757312149438
# R^2 Score: 0.88

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
from sklearn.metrics import r2_score

# Calculate the R^2 score


# Calculate error metrics
mae = mean_absolute_error(interpolated_extension_ratio_s, predictions_example_s)
mse = mean_squared_error(interpolated_extension_ratio_s, predictions_example_s)
r2 = r2_score(interpolated_extension_ratios, predictions_example_s)
rmse = np.sqrt(mse)

# Print the error metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R^2 Score: {r2:.2f}")

# Optionally, plot the difference between the actual and predicted values
plt.plot(wavelength_range_example_s, predictions_example_s, label='Predictions')
plt.plot(wavelength_range, interpolated_extension_ratio_s, label='Actual')
plt.grid(True)
plt.legend()
# Out:
# Mean Absolute Error (MAE): 0.1509919363258835
# Mean Squared Error (MSE): 0.029158751417388
# Root Mean Squared Error (RMSE): 0.17075933771653015
# R^2 Score: 0.32

# %%
10*np.log(predictions_example/predictions_example_s)
# Out:
# array([[-0.3439017 ],
#        [-0.34083125],
#        [-0.33777833],
#        ...,
#        [ 0.47326976],
#        [ 0.4711866 ],
#        [ 0.4691041 ]], dtype=float32)

# %%
wavelength = df1['Wavelength (nm)'].values
extension_ratio = df1['ER'].values

interpolation_function = interp1d(wavelength, extension_ratio, kind='linear', fill_value='extrapolate')

wavelength_range = np.linspace(wavelength.min(), wavelength.max(), data)
interpolated_extension_ratio_er = interpolation_function(wavelength_range)

# Calculate error metrics
mae = mean_absolute_error(interpolated_extension_ratio_er, 10*np.log(predictions_example/predictions_example_s))
mse = mean_squared_error(interpolated_extension_ratio_er, 10*np.log(predictions_example/predictions_example_s))
r2 = r2_score(interpolated_extension_ratio_er, 10*np.log(predictions_example/predictions_example_s))
rmse = np.sqrt(mse)


print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R^2 Score: {r2:.2f}")


plt.plot(wavelength_range_example, 10*np.log(predictions_example/predictions_example_s), label='Predictions')
plt.plot(wavelength_range, interpolated_extension_ratio_er, label='Actual')
plt.grid(True)
plt.legend()
# Out:
# Mean Absolute Error (MAE): 2.2152723866742594
# Mean Squared Error (MSE): 11.213325660637315
# Root Mean Squared Error (RMSE): 3.348630415653139
# R^2 Score: -2.68
